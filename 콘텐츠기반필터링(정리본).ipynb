# %% [markdown]
# <a href="https://colab.research.google.com/github/tunEmvegnomb/cook_alone/blob/main/%EC%BD%98%ED%85%90%EC%B8%A0%EA%B8%B0%EB%B0%98%ED%95%84%ED%84%B0%EB%A7%81(%EC%A0%95%EB%A6%AC%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id=4
#사람이 클릭한 레시피의 아이디

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
#한글문장을 토근화해줌
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 15.30 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# %cd 'Mecab-ko-for-Google-Colab'
# !bash install_mecab-ko_on_colab_light_220429.sh #맥캡설치 복잡해서 그냥 pip로는 설치 안되고 쉘 스크립트 형태로 받아주는것
# Out:
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 799 kB/s
# ...
#      |████████████████████████████████| 453 kB 68.7 MB/s
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-06-09 22:42:42--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::3403:4be7, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import pandas as pd
from konlpy.tag import Mecab #문장을 토큰화
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
df = pd.read_table('/content/RECIPES2.csv', sep=',')

# %%
mecab = Mecab()

df['token']=0 #토큰 자리에0을 넣어서 열을 만들어줌

# %%
for i in range(0, len(df['cookstep'])):
  tmp = mecab.nouns(str(df['cookstep'][i]))
  df['token'][i] = tmp #토큰 단위로 나눠봄
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(df['token'])] #태그 다큐먼트 형태여야 doc2vec을 할 수 있어서 전처리한것

# %%
token_list={}

# %%
for i, doc in enumerate(df['token']):
  print(i+1, doc)
  token_list[i+1]=doc
# Out:
# 1 ['찹쌀', '찹쌀', '찹쌀', '때', '물', '번', '정도', '반복', '찹쌀', '물', '시간', '준비', '찹쌀', '시간', '정도', '찹쌀', '분쇄기', '찹쌀', '양', '시간', '찹쌀', '번', '중간', '번', '찹쌀', '다음', '찹쌀', '찹쌀', '양', '번', '정도', '반복', '찹쌀', '분쇄기', '찹쌀가루', '찹쌀', '가루', '채', '밭', '다음', '번', '채', '떡', '맛', '채', '것', '분쇄기', '준비', '찹쌀', '가루', '간', '후', '천일염', '술', '설탕', '술', '아진', '찹쌀', '간', '간', '천일염', '술', '방부제', '역할', '설탕', '술', '소금', '수', '다음', '찹쌀', '가루', '손', '손', '물', '양', '손', '물', '양', '부족', '뜻', '때', '물', '조절', '찹쌀', '면', '보자기', '수', '때', '물', '다음', '찹쌀', '가루', '찜', '솥', '양', '분', '뚜껑', '찜', '솥', '요즘', '찜', '솥', '밀가루', '참고', '찰떡', '다음', '완성', '센불', '찰떡', '분', '간', '뚜껑', '떡', '확인', '젓가락', '떡', '가루', '신호', '가루', '분', '찰떡', '분', '뜸', '뜸', '다음', '뜸', '찰떡', '다음', '모양', '면', '보자기', '물', '다음', '찰떡', '번', '찰떡', '절구', '방망이', '맛', '방망이', '손', '모양', '자', '때', '찰떡', '참기름', '방망이', '손', '모양', '때', '방망이', '추천', '칼', '참기름', '찰떡', '세로', '찰떡', '맛', '찰떡', '입', '가로', '다음', '찰떡', '다음', '찰떡', '조청', '꿀', '저희', '조청', '사과', '조청', '식성', '꿀', '흑설탕', '물'
# ...

# %%
print(token_list)
# Out:
# {0: ['찹쌀', '찹쌀', '찹쌀', '때', '물', '번', '정도', '반복', '찹쌀', '물', '시간', '준비', '찹쌀', '시간', '정도', '찹쌀', '분쇄기', '찹쌀', '양', '시간', '찹쌀', '번', '중간', '번', '찹쌀', '다음', '찹쌀', '찹쌀', '양', '번', '정도', '반복', '찹쌀', '분쇄기', '찹쌀가루', '찹쌀', '가루', '채', '밭', '다음', '번', '채', '떡', '맛', '채', '것', '분쇄기', '준비', '찹쌀', '가루', '간', '후', '천일염', '술', '설탕', '술', '아진', '찹쌀', '간', '간', '천일염', '술', '방부제', '역할', '설탕', '술', '소금', '수', '다음', '찹쌀', '가루', '손', '손', '물', '양', '손', '물', '양', '부족', '뜻', '때', '물', '조절', '찹쌀', '면', '보자기', '수', '때', '물', '다음', '찹쌀', '가루', '찜', '솥', '양', '분', '뚜껑', '찜', '솥', '요즘', '찜', '솥', '밀가루', '참고', '찰떡', '다음', '완성', '센불', '찰떡', '분', '간', '뚜껑', '떡', '확인', '젓가락', '떡', '가루', '신호', '가루', '분', '찰떡', '분', '뜸', '뜸', '다음', '뜸', '찰떡', '다음', '모양', '면', '보자기', '물', '다음', '찰떡', '번', '찰떡', '절구', '방망이', '맛', '방망이', '손', '모양', '자', '때', '찰떡', '참기름', '방망이', '손', '모양', '때', '방망이', '추천', '칼', '참기름', '찰떡', '세로', '찰떡', '맛', '찰떡', '입', '가로', '다음', '찰떡', '다음', '찰떡', '조청', '꿀', '저희', '조청', '사과', '조청', '식성', '꿀', '흑설탕', '
# ...

# %%
model = Doc2Vec(documents, vector_size=100, window=3, epochs=10, min_count=0, workers=4) #벡터화 모델

# %%
inferred_doc_vec = model.infer_vector(df['token'][n-1])
print(inferred_doc_vec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-63271b4fbf3c> in <module>()
# ----> 1 inferred_doc_vec = model.infer_vector(df['token'][n-1])
#       2 print(inferred_doc_vec)
#
# NameError: name 'n' is not defined

# %%
infer_vector_list=[]

# %%
inferred_doc_vec_1 = model.infer_vector(df['token'][0])
print(inferred_doc_vec_1)
# Out:
# [-0.36607346  0.07315645 -0.08424443 -0.51628196  0.46363285 -0.15362136
#   0.2972796   0.15798147  0.08586222  0.64398104 -0.13777229 -0.08626585
#  -0.03227146  0.3186133   0.27203608  0.36384106 -0.0942244   0.4359929
#  -0.10474998 -0.34211713  0.31898344 -0.08180864 -0.27619562 -0.3641432
#   0.4588452   0.25423738  0.08230744 -0.05529404  0.12624918  0.2364682
#  -0.3278729  -0.01065916  0.23589247 -0.17445102 -0.10960302  0.35106912
#  -0.04976287 -0.7366443  -0.9844435  -0.34843323 -0.3609849  -0.49904585
#   0.37325853 -0.12112894  0.22095135  0.80564946 -0.17513476  0.04701585
#   0.6849333   0.21955535 -0.24569394  0.15832818 -0.30241126  0.40156603
#   0.3262779  -0.33890426  0.34971586  0.3488525   0.2615047   0.06902263
#   0.25479203 -0.45525265  0.10115443 -0.28079107 -0.09644531  0.04072248
#  -0.34960186  0.11645716  0.9082061   0.6990925  -0.25538546 -1.214155
#  -0.23685212 -0.340768   -0.16542943 -0.27297992  0.3489731  -0.5538469
# ...

# %%
inferred_doc_vec_1958 = model.infer_vector(df['token'][1957])
print(inferred_doc_vec_1958)
# Out:
# [ 2.90150121e-02  2.60665994e-02 -7.76476413e-02 -2.24441707e-01
#   5.11124283e-02 -9.05376747e-02 -2.47403905e-02  1.58662368e-02
#   2.49351980e-03  1.36653244e-01  2.21305743e-01 -4.14100550e-02
#  -1.45358205e-01  1.41135797e-01  1.76177561e-01  6.44905120e-02
#   1.47452950e-01  3.28593329e-02 -5.73180206e-02 -1.71472028e-01
#  -4.37650271e-02 -2.20893882e-02  8.51583928e-02 -1.08290732e-01
#   1.94614604e-01  2.91336179e-02 -5.17680310e-03  1.04591027e-01
#   8.11489746e-02  1.50254726e-01 -2.03661516e-01 -2.05590189e-01
#   9.07029584e-03  9.79422182e-02  7.71977156e-02  1.08534530e-01
#   7.74319991e-02 -4.35255878e-02 -3.03955078e-01 -5.19390032e-02
#  -7.39020668e-03 -1.58373475e-01 -2.14650650e-02 -1.04209250e-02
#  -1.43861711e-01  8.76240805e-02  4.79157344e-02  2.26616059e-04
#   1.19872876e-01  2.33022925e-02  6.20562173e-02  1.42253011e-01
#  -1.70685336e-01 -1.58991650e-01  1.91246178e-02  1.87426265e-02
# ...

# %%
for i in range(1958):
  inferred_doc_vec = model.infer_vector(df['token'][i])
  infer_vector_list.append(inferred_doc_vec)
#0번부터 1949번까지의 벡터 리스트

# %%
print(infer_vector_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
most_similar_docs = model.docvecs.most_similar([inferred_doc_vec], topn=5)
print(most_similar_docs)
# for index, similarity in most_similar_docs:
#   print(f'{index}, similarity:{similarity}')
#   print(documents[index])
# Out:
# [(1957, 0.9563307762145996), (671, 0.9433871507644653), (905, 0.9407656192779541), (1595, 0.937288224697113), (1448, 0.9355795383453369)]
